# %%
from sklearn.datasets import make_classification

# %%
X,y=make_classification(n_samples=1000,n_features=2,n_redundant=0,n_clusters_per_class=1,weights=[0.90],random_state=12)

# %%
import pandas as pd
df1=pd.DataFrame(X,columns=['f1','f2'])
df2=pd.DataFrame(y,columns=['target'])
final_df=pd.concat([df1,df2],axis=1)
final_df.head()
# Out:
#          f1        f2  target
# 0 -0.762898 -0.706808       0
# 1 -1.075436 -1.051162       0
# 2 -0.610115 -0.909802       0
# 3 -2.023284 -0.428945       1
# 4 -0.812921 -1.316206       0

# %%
final_df['target'].value_counts()
# Out:
# 0    900
# 1    100
# Name: target, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'],final_df['f2'],c=final_df['target'])

# %%
# !pip install imblearn --user --trusted-host pypi.org --trusted-host files.pythonhosted.org
# Out:
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0
#     Uninstalling scikit-learn-1.0:
#       Successfully uninstalled scikit-learn-1.0
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\AG89277\\AppData\\Roaming\\Python\\Python39\\site-packages\\~klearn\\.libs\\vcomp140.dll'
# Check the permissions.
